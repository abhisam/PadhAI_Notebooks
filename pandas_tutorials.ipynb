# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisam/PadhAI_Notebooks/blob/master/pandas_tutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read a csv file
# converting date object fields to date type
flights = pd.read_csv("ny-flights.csv.gz",
                      parse_dates=["fl_date", "arr", "dep"])
flights
# Out:
#          fl_date unique_carrier  airline_id tail_num  fl_num origin dest  \
# 0     2014-01-01             AA       19805   N338AA       1    JFK  LAX
# 1     2014-01-01             AA       19805   N335AA       3    JFK  LAX
# 2     2014-01-01             AA       19805   N327AA      21    JFK  LAX
# 3     2014-01-01             AA       19805   N3EHAA      29    LGA  PBI
# 4     2014-01-01             AA       19805   N319AA     117    JFK  LAX
# 5     2014-01-01             AA       19805   N323AA     185    JFK  LAX
# 6     2014-01-01             AA       19805   N328AA     133    JFK  LAX
# 7     2014-01-01             AA       19805   N5FJAA     145    JFK  MIA
# 8     2014-01-01             AA       19805   N3HYAA     235    JFK  SEA
# 9     2014-01-01             AA       19805   N332AA     177    JFK  SFO
# 10    2014-01-01             AA       19805   N3JWAA     178    JFK  BOS
# 11    2014-01-01             AA       19805   N336AA     181    JFK  LAX
# ...

# %%
# data types
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20817 entries, 0 to 20816
# Data columns (total 14 columns):
# fl_date           20817 non-null datetime64[ns]
# unique_carrier    20817 non-null object
# airline_id        20817 non-null int64
# tail_num          20512 non-null object
# fl_num            20817 non-null int64
# origin            20817 non-null object
# dest              20817 non-null object
# dep_time          18462 non-null float64
# dep_delay         18462 non-null float64
# arr_time          18412 non-null float64
# arr_delay         18383 non-null float64
# cancelled         20817 non-null float64
# arr               18412 non-null datetime64[ns]
# dep               18462 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(5), int64(2), object(4)
# memory usage: 2.2+ MB

# %%
# columns
flights.columns
# Out:
# Index(['fl_date', 'unique_carrier', 'airline_id', 'tail_num', 'fl_num',
#        'origin', 'dest', 'dep_time', 'dep_delay', 'arr_time', 'arr_delay',
#        'cancelled', 'arr', 'dep'],
#       dtype='object')

# %%
# selecting single column 
flights['unique_carrier']
# Out:
# 0        AA
# 1        AA
# 2        AA
# 3        AA
# 4        AA
# 5        AA
# 6        AA
# 7        AA
# 8        AA
# 9        AA
# 10       AA
# 11       AA
# 12       AA
# 13       AA
# 14       AA
# 15       AA
# 16       AA
# 17       AA
# 18       AA
# 19       AA
# 20       AA
# 21       AA
# 22       AA
# 23       AA
# 24       AA
# 25       AA
# 26       AA
# 27       AA
# 28       AA
# 29       AA
#          ..
# 20787    UA
# 20788    UA
# 20789    UA
# 20790    UA
# 20791    UA
# 20792    UA
# 20793    UA
# 20794    UA
# 20795    UA
# 20796    UA
# 20797    UA
# 20798    MQ
# 20799    UA
# 20800    UA
# 20801    UA
# 20802    UA
# 20803    UA
# 20804    UA
# 20805    UA
# 20806    UA
# 20807    UA
# 20808    UA
# 20809    UA
# 20810    UA
# 20811    UA
# 20812    UA
# 20813    UA
# 20814    UA
# 20815    UA
# 20816    MQ
# Name: unique_carrier, Length: 20817, dtype: object

# %%
# selecting multiple columns 
flights[['fl_date', 'airline_id']]
# Out:
#          fl_date  airline_id
# 0     2014-01-01       19805
# 1     2014-01-01       19805
# 2     2014-01-01       19805
# 3     2014-01-01       19805
# 4     2014-01-01       19805
# 5     2014-01-01       19805
# 6     2014-01-01       19805
# 7     2014-01-01       19805
# 8     2014-01-01       19805
# 9     2014-01-01       19805
# 10    2014-01-01       19805
# 11    2014-01-01       19805
# 12    2014-01-01       19805
# 13    2014-01-01       19805
# 14    2014-01-01       19805
# 15    2014-01-01       19805
# 16    2014-01-01       19805
# 17    2014-01-01       19805
# 18    2014-01-01       19805
# 19    2014-01-01       19805
# 20    2014-01-01       19805
# 21    2014-01-01       19805
# 22    2014-01-01       19805
# 23    2014-01-01       19805
# 24    2014-01-01       19805
# 25    2014-01-01       19805
# 26    2014-01-01       19805
# 27    2014-01-01       19805
# 28    2014-01-01       19805
# 29    2014-01-01       19805
# ...          ...         ...
# ...

# %%
# fininding indexes of dataframe, starting ending of dataframe indexes
flights.index
# Out:
# RangeIndex(start=0, stop=20817, step=1)

# %%
# finding count of each aireline types
flights['unique_carrier'].value_counts()
# Out:
# B6    4902
# DL    3803
# MQ    2434
# AA    2427
# EV    2080
# WN    1917
# US    1568
# UA    1106
# VX     301
# FL     206
# F9      33
# HA      29
# OO      11
# Name: unique_carrier, dtype: int64

# %%
flights['unique_carrier'].value_counts()
# Out:
# B6    4902
# DL    3803
# MQ    2434
# AA    2427
# EV    2080
# WN    1917
# US    1568
# UA    1106
# VX     301
# FL     206
# F9      33
# HA      29
# OO      11
# Name: unique_carrier, dtype: int64

# %%
# countind coulumn data by group
flights['dep'].value_counts()
# Out:
# 2014-01-20 12:57:00    7
# 2014-01-24 06:50:00    7
# 2014-01-16 06:55:00    7
# 2014-01-25 05:56:00    6
# 2014-01-24 05:56:00    6
# 2014-01-09 12:00:00    6
# 2014-01-14 05:52:00    6
# 2014-01-16 05:56:00    6
# 2014-01-16 08:00:00    6
# 2014-01-17 06:53:00    6
# 2014-01-10 05:56:00    6
# 2014-01-21 05:56:00    6
# 2014-01-09 07:58:00    6
# 2014-01-20 05:57:00    5
# 2014-01-20 08:57:00    5
# 2014-01-26 14:54:00    5
# 2014-01-20 17:28:00    5
# 2014-01-23 06:30:00    5
# 2014-01-23 19:31:00    5
# 2014-01-20 15:42:00    5
# 2014-01-31 11:52:00    5
# 2014-01-13 06:50:00    5
# 2014-01-31 10:25:00    5
# 2014-01-14 07:55:00    5
# 2014-01-17 06:57:00    5
# 2014-01-19 06:58:00    5
# 2014-01-23 16:16:00    5
# 2014-01-20 07:59:00    5
# 2014-01-27 07:55:00    5
# 2014-01-01 18:59:00    5
#                       ..
# 2014-01-11 07:26:00    1
# 2014-01-27 14:22:00    1
# 2014-01-04 14:09:00    1
# 2014-01-24 17:56:00    1
# 2014-01-20 21:05:00    1
# 2014-01-25 08:35:00    1
# ...

# %%
# sampling time series data by Hours like grouping data by hour and counting
flights['dep'].value_counts().resample('H').sum()
# Out:
# 2014-01-01 00:00:00     3
# 2014-01-01 01:00:00     0
# 2014-01-01 02:00:00     0
# 2014-01-01 03:00:00     0
# 2014-01-01 04:00:00     0
# 2014-01-01 05:00:00    11
# 2014-01-01 06:00:00    30
# 2014-01-01 07:00:00    41
# 2014-01-01 08:00:00    43
# 2014-01-01 09:00:00    41
# 2014-01-01 10:00:00    26
# 2014-01-01 11:00:00    36
# 2014-01-01 12:00:00    31
# 2014-01-01 13:00:00    31
# 2014-01-01 14:00:00    37
# 2014-01-01 15:00:00    45
# 2014-01-01 16:00:00    32
# 2014-01-01 17:00:00    50
# 2014-01-01 18:00:00    44
# 2014-01-01 19:00:00    31
# 2014-01-01 20:00:00    27
# 2014-01-01 21:00:00    13
# 2014-01-01 22:00:00    12
# 2014-01-01 23:00:00     9
# 2014-01-02 00:00:00     3
# 2014-01-02 01:00:00     3
# 2014-01-02 02:00:00     1
# 2014-01-02 03:00:00     1
# 2014-01-02 04:00:00     0
# 2014-01-02 05:00:00    10
#                        ..
# 2014-01-30 18:00:00    42
# 2014-01-30 19:00:00    33
# 2014-01-30 20:00:00    36
# 2014-01-30 21:00:00    15
# ...

# %%
#Calculate Rolling Mean
#the first 8 values, average them, 
# then drop the 7 values and add the 9th value, etc

flights['dep'].value_counts().resample('H').sum().rolling(8).mean()
# Out:
# 2014-01-01 00:00:00       NaN
# 2014-01-01 01:00:00       NaN
# 2014-01-01 02:00:00       NaN
# 2014-01-01 03:00:00       NaN
# 2014-01-01 04:00:00       NaN
# 2014-01-01 05:00:00       NaN
# 2014-01-01 06:00:00       NaN
# 2014-01-01 07:00:00    10.625
# 2014-01-01 08:00:00    15.625
# 2014-01-01 09:00:00    20.750
# 2014-01-01 10:00:00    24.000
# 2014-01-01 11:00:00    28.500
# 2014-01-01 12:00:00    32.375
# 2014-01-01 13:00:00    34.875
# 2014-01-01 14:00:00    35.750
# 2014-01-01 15:00:00    36.250
# 2014-01-01 16:00:00    34.875
# 2014-01-01 17:00:00    36.000
# 2014-01-01 18:00:00    38.250
# 2014-01-01 19:00:00    37.625
# 2014-01-01 20:00:00    37.125
# 2014-01-01 21:00:00    34.875
# 2014-01-01 22:00:00    31.750
# 2014-01-01 23:00:00    27.250
# 2014-01-02 00:00:00    23.625
# 2014-01-02 01:00:00    17.750
# 2014-01-02 02:00:00    12.375
# 2014-01-02 03:00:00     8.625
# 2014-01-02 04:00:00     5.250
# 2014-01-02 05:00:00     4.875
#                         ...
# ...

# %%
#plotting time series data of departure with rolloing avg

(flights['dep']
    .value_counts()
    .resample('H')
    .sum()
    .rolling(8).mean()
    .plot(figsize=(12, 6),
          title="Number of Flights (8H Rolling Mean)"))
sns.despine()

# %%
sns.countplot(
    flights['unique_carrier'],
    order=flights['unique_carrier'].value_counts().index,
    palette='Blues_r'
)
sns.despine()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# PLOTTING COUNT OF FLIGHTS PER CARRIER
sns.countplot(
    flights['unique_carrier'],
    order=flights['unique_carrier'].value_counts().index,
    palette='Blues_r'
)
#sns.despine()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# plotting counter plot for count of departure per location

sns.countplot(flights['origin'], order= flights['origin'].value_counts().index, palette='muted')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ##(square brackets) to select columns of a DataFrame
#
# #### >>> df[['a', 'b', 'c']]
# ## Use .loc for label-based indexing (rows and columns)
#
# #### >>> df.loc[row_labels, column_labels]
# ##Use .iloc for position-based indexing (rows and columns)
#
# ####>>> df.iloc[row_positions, column_positions]

# %% [markdown]
# The arguments to .loc and .iloc are .loc[row_indexer, column_indexer]. An indexer can be one of
#
# - A scalar or array (of labels or integer positions)
# - A slice object (including : for everything)
# - A boolean mask
# - The column indexer is optional. We'll walk through all the combinations below.

# %%
#DataFrame with a labeled index by selecting the first flight for each carrier.
first = flights.groupby("unique_carrier").first()
first
# Out:
#                   fl_date  airline_id tail_num  fl_num origin dest  dep_time  \
# unique_carrier
# AA             2014-01-01       19805   N338AA       1    JFK  LAX     914.0
# B6             2014-01-01       20409   N318JB     115    SYR  JFK     720.0
# DL             2014-01-01       19790   N930DL      61    LGA  ATL    1810.0
# EV             2014-01-01       20366   N14977    3259    HPN  ORD     731.0
# F9             2014-01-01       20436   N209FR     507    LGA  DEN    1804.0
# FL             2014-01-01       20437   N952AT      63    LGA  ATL    1146.0
# HA             2014-01-01       19690   N382HA      51    JFK  HNL     906.0
# MQ             2014-01-01       20398   N521MQ    2789    LGA  CLT    1328.0
# OO             2014-01-07       20304   N732SK    6258    SYR  ORD    1721.0
# UA             2014-01-01       19977   N413UA     255    LGA  ORD     824.0
# US             2014-01-01       20355   N546UW     629    JFK  PHX    1624.0
# ...

# %%
# builing a list of cols and slice them

cols = ['dep_delay', 'arr_delay']
first[cols]
# Out:
#                 dep_delay  arr_delay
# unique_carrier
# AA                   14.0       13.0
# B6                   90.0       55.0
# DL                   10.0       10.0
# EV                   -5.0       31.0
# F9                   35.0       47.0
# FL                   -5.0      -10.0
# HA                    6.0       -7.0
# MQ                    8.0        2.0
# OO                   49.0       47.0
# UA                    0.0        8.0
# US                   -6.0      -39.0
# VX                    0.0      -14.0
# WN                   17.0       15.0

# %%
first[['origin','dest']]
# Out:
#                origin dest
# unique_carrier
# AA                JFK  LAX
# B6                SYR  JFK
# DL                LGA  ATL
# EV                HPN  ORD
# F9                LGA  DEN
# FL                LGA  ATL
# HA                JFK  HNL
# MQ                LGA  CLT
# OO                SYR  ORD
# UA                LGA  ORD
# US                JFK  PHX
# VX                JFK  SFO
# WN                ALB  BWI

# %%
flights.tail_num.value_counts()
# Out:
# N292JB    76
# N258JB    69
# N306JB    68
# N523MQ    59
# N324JB    58
# N192JB    57
# N236JB    57
# N534MQ    56
# N843MQ    55
# N193JB    55
# N525MQ    54
# N266JB    53
# N532MQ    51
# N203JB    51
# N178JB    50
# N334JB    50
# N373JB    49
# N501MQ    49
# N845MQ    47
# N355JB    47
# N283JB    47
# N6EAMQ    46
# N216JB    45
# N337JB    45
# N539MQ    44
# N281JB    43
# N838MQ    43
# N615QX    43
# N351JB    43
# N354JB    42
#           ..
# N945DN     1
# N501AA     1
# N345SA     1
# N657SW     1
# N521US     1
# N431UA     1
# N350AA     1
# N468UA     1
# N5FDAA     1
# N827MH     1
# N557AA     1
# N360AA     1
# N473AA     1
# N136EV     1
# N189DN     1
# N5EEAA     1
# N76508     1
# N4XDAA     1
# N202FR     1
# N624SW     1
# N7702A     1
# N13132     1
# N390SW     1
# N436UA     1
# N3HGAA     1
# N279WN     1
# N612SW     1
# N337NW     1
# N427UA     1
# N76288     1
# Name: tail_num, Length: 2734, dtype: int64

# %%
x = pd.DataFrame({"mean": [1, 2, 3]})
x
# Out:
#    mean
# 0     1
# 1     2
# 2     3

# %%
# returns the method, not the column
x.mean
# Out:
# <bound method DataFrame.mean of    mean
# 0     1
# 1     2
# 2     3>

# %%
# you can't assign with ., while you can with __setitem__ (square brackets on the left-hand side of an =):
# addning new columns

x.wrong = ['a', 'b', 'c']
x['right'] = ['a', 'b', 'c']
x
# Out:
#    mean right
# 0     1     a
# 1     2     b
# 2     3     c

# %%
x.wrong
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# # Label-Based Indexing with .loc

# %%
carriers = ['AA', 'DL', 'US', 'WN']
# Select those carriers by label
first.loc[carriers]
# no column indexer
# Out:
#                   fl_date  airline_id tail_num  fl_num origin dest  dep_time  \
# unique_carrier
# AA             2014-01-01       19805   N338AA       1    JFK  LAX     914.0
# DL             2014-01-01       19790   N930DL      61    LGA  ATL    1810.0
# US             2014-01-01       20355   N546UW     629    JFK  PHX    1624.0
# WN             2014-01-01       19393   N625SW     613    ALB  BWI    1502.0
#
#                 dep_delay  arr_time  arr_delay  cancelled                 arr  \
# unique_carrier
# AA                   14.0    1238.0       13.0        0.0 2014-01-01 12:38:00
# DL                   10.0    2054.0       10.0        0.0 2014-01-01 20:54:00
# US                   -6.0    1932.0      -39.0        0.0 2014-01-01 19:32:00
# WN                   17.0    1615.0       15.0        0.0 2014-01-01 16:15:00
#
#                                dep
# unique_carrier
# AA             2014-01-01 09:14:00
# DL             2014-01-01 18:10:00
# ...

# %%
first
# Out:
#                   fl_date  airline_id tail_num  fl_num origin dest  dep_time  \
# unique_carrier
# AA             2014-01-01       19805   N338AA       1    JFK  LAX     914.0
# B6             2014-01-01       20409   N318JB     115    SYR  JFK     720.0
# DL             2014-01-01       19790   N930DL      61    LGA  ATL    1810.0
# EV             2014-01-01       20366   N14977    3259    HPN  ORD     731.0
# F9             2014-01-01       20436   N209FR     507    LGA  DEN    1804.0
# FL             2014-01-01       20437   N952AT      63    LGA  ATL    1146.0
# HA             2014-01-01       19690   N382HA      51    JFK  HNL     906.0
# MQ             2014-01-01       20398   N521MQ    2789    LGA  CLT    1328.0
# OO             2014-01-07       20304   N732SK    6258    SYR  ORD    1721.0
# UA             2014-01-01       19977   N413UA     255    LGA  ORD     824.0
# US             2014-01-01       20355   N546UW     629    JFK  PHX    1624.0
# ...

# %%
# select just `carriers` and origin, dest, and dep_delay
# Indexing both rows and columns:

first.loc[carriers, ['origin', 'dest', 'dep_delay']]
# Out:
#                origin dest  dep_delay
# unique_carrier
# AA                JFK  LAX       14.0
# DL                LGA  ATL       10.0
# US                JFK  PHX       -6.0
# WN                ALB  BWI       17.0

# %%
# select just tail_num for those `carriers`

first.loc[carriers, 'tail_num']
# Out:
# unique_carrier
# AA    N338AA
# DL    N930DL
# US    N546UW
# WN    N625SW
# Name: tail_num, dtype: object

# %%
#And scalars on both axes will return a scalar.

first.loc['AA', 'tail_num']
# Out:
# 'N338AA'

# %%
# You can pass a slice object (made with a :). They make sense when your index is sorted, which ours is.
# slice from AA to DL
first.loc['AA':'DL']
# Out:
#                   fl_date  airline_id tail_num  fl_num origin dest  dep_time  \
# unique_carrier
# AA             2014-01-01       19805   N338AA       1    JFK  LAX     914.0
# B6             2014-01-01       20409   N318JB     115    SYR  JFK     720.0
# DL             2014-01-01       19790   N930DL      61    LGA  ATL    1810.0
#
#                 dep_delay  arr_time  arr_delay  cancelled                 arr  \
# unique_carrier
# AA                   14.0    1238.0       13.0        0.0 2014-01-01 12:38:00
# B6                   90.0     808.0       55.0        0.0 2014-01-01 08:08:00
# DL                   10.0    2054.0       10.0        0.0 2014-01-01 20:54:00
#
#                                dep
# unique_carrier
# AA             2014-01-01 09:14:00
# B6             2014-01-01 07:20:00
# DL             2014-01-01 18:10:00

# %%
# Select the columns `tail_num`, `origin`, and `dest` for the carriers `US`, `VX`, and `WN` from `first`.

first.loc['US' : 'WN', ['tail_num','origin', 'dest']]
# Out:
#                tail_num origin dest
# unique_carrier
# US               N546UW    JFK  PHX
# VX               N361VA    JFK  SFO
# WN               N625SW    ALB  BWI

# %% [markdown]
# # Boolean Indexing

# %%
# Get the counts for `flights.origin`
origin_counts = flights.origin.value_counts()
origin_counts
# Out:
# LGA    8530
# JFK    7878
# BUF    1348
# ROC     676
# HPN     615
# ALB     593
# SYR     554
# ISP     398
# ELM     105
# SWF      62
# ART      58
# Name: origin, dtype: int64

# %%
# Get a boolean mask for whether `counts` is in the top 5.
top5 = origin_counts.index[:5]
top5
# Out:
# Index(['LGA', 'JFK', 'BUF', 'ROC', 'HPN'], dtype='object')

# %%
origin_counts
# Out:
# LGA    8530
# JFK    7878
# BUF    1348
# ROC     676
# HPN     615
# ALB     593
# SYR     554
# ISP     398
# ELM     105
# SWF      62
# ART      58
# Name: origin, dtype: int64

# %%
# We'll test whether any given row from flights is in the top 5 using the .isin method:

mask = flights.origin.isin(top5)
mask
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 20787    True
# 20788    True
# 20789    True
# 20790    True
# 20791    True
# 20792    True
# 20793    True
# 20794    True
# 20795    True
# 20796    True
# 20797    True
# 20798    True
# 20799    True
# 20800    True
# 20801    True
# 20802    True
# 20803    True
# 20804    True
# 20805    True
# 20806    True
# 20807    True
# 20808    True
# 20809    True
# 20810    True
# 20811    True
# 20812    True
# 20813    True
# 20814    True
# 20815    True
# 20816    True
# ...

# %%
# This is a boolean mask, which can be passed into .loc.

flights.loc[mask, ['origin', 'dest']]
# Out:
#       origin dest
# 0        JFK  LAX
# 1        JFK  LAX
# 2        JFK  LAX
# 3        LGA  PBI
# 4        JFK  LAX
# 5        JFK  LAX
# 6        JFK  LAX
# 7        JFK  MIA
# 8        JFK  SEA
# 9        JFK  SFO
# 10       JFK  BOS
# 11       JFK  LAX
# 12       JFK  BOS
# 13       JFK  ORD
# 14       JFK  IAH
# 15       JFK  AUS
# 16       LGA  ORD
# 17       LGA  ORD
# 18       LGA  ORD
# 19       LGA  ORD
# 20       LGA  ORD
# 21       LGA  ORD
# 22       LGA  ORD
# 23       LGA  ORD
# 24       LGA  ORD
# 25       LGA  ORD
# 26       LGA  ORD
# 27       LGA  ORD
# 28       JFK  STT
# 29       LGA  ORD
# ...      ...  ...
# 20787    JFK  SFO
# 20788    JFK  SFO
# 20789    JFK  LAX
# 20790    LGA  IAH
# 20791    LGA  IAH
# 20792    LGA  IAH
# 20793    LGA  DEN
# 20794    JFK  SFO
# 20795    LGA  DEN
# 20796    JFK  LAX
# 20797    LGA  DEN
# 20798    LGA  CLT
# 20799    BUF  ORD
# 20800    JFK  SFO
# 20801    LGA  IAH
# 20802    LGA  ORD
# 20803    LGA  ORD
# 20804    LGA  ORD
# ...

# %% [markdown]
# ### You can pass boolean masks to regular [], .loc, or .iloc.
#
#   - Boolean indexers are useful because so many operations can produce  an array of booleans.
#
# - null checks (.isnull, .notnull)
# - container checks (.isin)
# - boolean aggregations (.any, .all)
# - comparisions (.gt, .lt, etc.)

# %%
# Select rows where `dep` is null

flights.loc[flights.dep.isnull()]
# Out:
#          fl_date unique_carrier  airline_id tail_num  fl_num origin dest  \
# 29    2014-01-01             AA       19805   N3EAAA     359    LGA  ORD
# 31    2014-01-01             AA       19805   N542AA     371    LGA  ORD
# 195   2014-01-01             B6       20409   N913JB    1103    JFK  SJU
# 209   2014-01-01             B6       20409   N193JB     518    JFK  BOS
# 359   2014-01-01             EV       20366   N17159    4130    SYR  CLE
# 360   2014-01-01             EV       20366   N14143    4159    LGA  CLE
# 362   2014-01-01             EV       20366   N15555    4261    LGA  CLE
# 391   2014-01-01             EV       20366   N48901    5994    BUF  ORD
# 405   2014-01-01             MQ       20398   N800MQ    2849    BUF  ORD
# 406   2014-01-01             MQ       20398   N635MQ    2753    SYR  ORD
# 409   2014-01-01             MQ       20398   N523MQ    2840    LGA  STL
# 417   2014-01-01             MQ       20398   N801MQ    3075    SYR  ORD
# ...

# %%
flights.loc[flights.cancelled == 1]
# Out:
#          fl_date unique_carrier  airline_id tail_num  fl_num origin dest  \
# 29    2014-01-01             AA       19805   N3EAAA     359    LGA  ORD
# 31    2014-01-01             AA       19805   N542AA     371    LGA  ORD
# 195   2014-01-01             B6       20409   N913JB    1103    JFK  SJU
# 209   2014-01-01             B6       20409   N193JB     518    JFK  BOS
# 359   2014-01-01             EV       20366   N17159    4130    SYR  CLE
# 360   2014-01-01             EV       20366   N14143    4159    LGA  CLE
# 362   2014-01-01             EV       20366   N15555    4261    LGA  CLE
# 391   2014-01-01             EV       20366   N48901    5994    BUF  ORD
# 405   2014-01-01             MQ       20398   N800MQ    2849    BUF  ORD
# 406   2014-01-01             MQ       20398   N635MQ    2753    SYR  ORD
# 409   2014-01-01             MQ       20398   N523MQ    2840    LGA  STL
# 417   2014-01-01             MQ       20398   N801MQ    3075    SYR  ORD
# ...
